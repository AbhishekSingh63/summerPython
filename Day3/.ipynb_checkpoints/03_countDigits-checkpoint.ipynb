# %%
num=int(input("Enter a number: "))
count=0
while num>0:
    count+=1
    num=num//10
print(count)
# Out:
# Enter a number:  6768
# 4

# %%
n=int(input("Enter a number: "))
c=0
for i in str(n):
    c+=1
print(c)
# Out:
# Enter a number:  6768
# 4
