# %%
num=int(input("Enter a number: "))
sum=0
while num>0:
    d=num%10
    sum+=d
    num=num//10
print(sum)
# Out:
# Enter a number:  345
# 12

# %%
n=int(input("Enter a number: "))
s=0
for i in str(n):
    s+=int(i)
print(s)
# Out:
# Enter a number:  345
# 12
