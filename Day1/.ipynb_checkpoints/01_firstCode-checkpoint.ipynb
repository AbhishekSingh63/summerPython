# %%
name="Abhishek"
rollNo=22
print(name)
print(rollNo)
# Out:
# Abhishek
# 22

# %%
department = input("Enter your dept: ")
print(department)
# Out:
# Enter your dept:  CSE
# CSE

# %%
year=int(input("Enter Year: "))
print(year)
# Out:
# Enter Year:  3
# 3

# %%
type(print)
# Out:
# builtin_function_or_method

# %%
type(rollNo)
# Out:
# int
