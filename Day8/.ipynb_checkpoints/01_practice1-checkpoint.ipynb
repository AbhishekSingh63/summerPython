# %%
city="Delhi"
def whichCity():
    print(city)
whichCity()
print(city)
# Out:
# Delhi
# Delhi

# %%
balance=1000
def deposit():
    global balance
    balance+=100
    print(balance)
def withdraw():
    global balance
    balance-=100
    print(balance)

deposit()
withdraw()
withdraw()
# Out:
# 1100
# 1000
# 900
