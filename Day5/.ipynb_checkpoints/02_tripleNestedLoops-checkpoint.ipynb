# %%
#Q1
for building in range(1,3):
    for floor in range(1,4):
        for room in range(1,5):
            print("Building ",building," Floor ",floor," Room ",room, end=" , ")
        print()
# Out:
# Building  1  Floor  1  Room  1 , Building  1  Floor  1  Room  2 , Building  1  Floor  1  Room  3 , Building  1  Floor  1  Room  4 ,
# Building  1  Floor  2  Room  1 , Building  1  Floor  2  Room  2 , Building  1  Floor  2  Room  3 , Building  1  Floor  2  Room  4 ,
# Building  1  Floor  3  Room  1 , Building  1  Floor  3  Room  2 , Building  1  Floor  3  Room  3 , Building  1  Floor  3  Room  4 ,
# Building  2  Floor  1  Room  1 , Building  2  Floor  1  Room  2 , Building  2  Floor  1  Room  3 , Building  2  Floor  1  Room  4 ,
# Building  2  Floor  2  Room  1 , Building  2  Floor  2  Room  2 , Building  2  Floor  2  Room  3 , Building  2  Floor  2  Room  4 ,
# Building  2  Floor  3  Room  1 , Building  2  Floor  3  Room  2 , Building  2  Floor  3  Room  3 , Building  2  Floor  3  Room  4 ,
