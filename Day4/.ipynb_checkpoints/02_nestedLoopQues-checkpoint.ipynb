# %%
#Q1
for i in range(3):
    for j in range(3):
        print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2

# %%
#Q2
for i in range(1,4):
    print("Row ",i)
    for j in range(1,4):
        print("Column ",j)
# Out:
# Row  1
# Column  1
# Column  2
# Column  3
# Row  2
# Column  1
# Column  2
# Column  3
# Row  3
# Column  1
# Column  2
# Column  3

# %%
#Q3
for i in range(1,4):
    for j in range(1,5):
        print("*",end="")
    print()
# Out:
# ****
# ****
# ****

# %%
#Q4
for i in range(1,4):
    for j in range(1,5):
        print(j,end="")
    print()
# Out:
# 1234
# 1234
# 1234

# %%
#Q5
for i in range(1,4):
    for j in range(1,5):
        print(chr(j+64),end="")
    print()
# Out:
# ABCD
# ABCD
# ABCD

# %%
#Q6
for i in range(1,4):
    for j in range(1,4):
        print(i*j,end=" ")
    print()
# Out:
# 1 2 3
# 2 4 6
# 3 6 9

# %%
#Q7
for i in range(1,5):
    for j in range(1,5):
        print(i,end="")
    print()
# Out:
# 1111
# 2222
# 3333
# 4444

# %%
#Q8
a=1
for i in range(1,4):
    for j in range(1,4):
        print(a,end="")
        a+=1
    print()
# Out:
# 123
# 456
# 789

# %%
#Q9
a=2
b=1
for i in range(1,4):
    for j in range(1,4):
        print(a*b,end=" ")
        b+=1
    print()
# Out:
# 2 4 6
# 8 10 12
# 14 16 18

# %% [raw]
# #Q10
# 00 01
# 10 11
# 20 21
