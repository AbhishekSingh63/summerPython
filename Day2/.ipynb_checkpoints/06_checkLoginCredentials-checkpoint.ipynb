# %%
id = input("Enter user id: ")
password = input("Enter password: ")

if 5 <= len(id) <= 16 and id[0]!='@':
    if len(password) >= 4:
        print("Valid Credentials")
    else:
        print("Password too short")
else:
    print("Invalid User ID")
# Out:
# Enter user id:  abhi234
# Enter password:  giji575
# Valid Credentials
