# %%
exp=float(input("Your work experience in years: "))
if exp==0:
    print("salary is: ",50000)
elif exp>0 and exp<=1:
    print("salary is: ",80000)
elif exp>1 and exp<=3:
    print("salary is: ",110000)
elif exp>3:
    print("salary is: ",140000)
# Out:
# Your work experience in years:  3.5
# salary is:  140000
